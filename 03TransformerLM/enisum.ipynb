# %%
import torch 
from einops import rearrange, einsum

# %%
D = torch.ones(2, 3, 4, 5)
A = torch.ones(4, 5)

# %%
Y = einsum(D, A, "... d_in, d_out d_in -> ... d_out") # 默认转置

# %%
Y.shape
# Out:
# torch.Size([2, 3, 4, 4])
